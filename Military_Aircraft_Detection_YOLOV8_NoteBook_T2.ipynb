# %%
# %matplotlib inline
# Tyler Boudreau
# Trained on Miitary Aircraft Detection Dataset: https://www.kaggle.com/datasets/a2015003713/militaryaircraftdetectiondataset
from pathlib import Path
import os
import shutil
import numpy as np
import pandas as pd
from tqdm import tqdm
data_dir = Path("C:\\Users\\Tyler\\Desktop\\Orig_Data_Aircraft_Detection")

# read image dir
image_paths = []
annotation_paths = []
# collect image paths and annotations
for file_name in sorted(os.listdir(data_dir / 'dataset')):
    file_name = Path(file_name)
    if file_name.suffix == '.jpg':
        image_paths.append(data_dir / 'dataset' / file_name)
    if file_name.suffix == '.csv':
        annotation_paths.append(data_dir / 'dataset' / file_name)

# %%
exclude_classes = ['YF23', 'XB70', 'Vulcan']

class_names = [class_name for class_name in sorted(os.listdir(data_dir / 'crop')) if class_name not in exclude_classes]

class2idx = {class_name: i for i, class_name in enumerate(class_names)}

def filter_images_by_class(images_dir, exclude_classes):
    image_files = os.listdir(images_dir)
    filtered_images = [image for image in image_files if any(exclude_class not in image for exclude_class in exclude_classes)]
    return filtered_images

# %%
class2idx
# Out:
# {'A10': 0,
#  'A400M': 1,
#  'AG600': 2,
#  'AV8B': 3,
#  'B1': 4,
#  'B2': 5,
#  'B52': 6,
#  'Be200': 7,
#  'C130': 8,
#  'C17': 9,
#  'C2': 10,
#  'C5': 11,
#  'E2': 12,
#  'E7': 13,
#  'EF2000': 14,
#  'F117': 15,
#  'F14': 16,
#  'F15': 17,
#  'F16': 18,
#  'F18': 19,
#  'F22': 20,
#  'F35': 21,
#  'F4': 22,
#  'J20': 23,
#  'JAS39': 24,
#  'MQ9': 25,
#  'Mig31': 26,
#  'Mirage2000': 27,
#  'P3': 28,
#  'RQ4': 29,
#  'Rafale': 30,
#  'SR71': 31,
#  'Su34': 32,
#  'Su57': 33,
#  'Tornado': 34,
#  'Tu160': 35,
#  'Tu95': 36,
#  'U2': 37,
#  'US2': 38,
#  'V22': 39}

# %%
def convert_bboxes_to_yolo_format(df: pd.DataFrame, class2idx: dict):
    df = df[df['class'].isin(class2idx.keys())]
    df['class'] = df['class'].apply(lambda x: class2idx[x]).values

    df['xmin'] = (df['xmin'] / df['width']).values
    df['ymin'] = (df['ymin'] / df['height']).values
    df['xmax'] = (df['xmax'] / df['width']).values
    df['ymax'] = (df['ymax'] / df['height']).values
    df['xc']   = (df['xmin'] + df['xmax']) / 2
    df['yc']   = (df['ymin'] + df['ymax']) / 2
    df['w']    = (df['xmax'] - df['xmin'])
    df['h']    = (df['ymax'] - df['ymin'])
    df.drop(
        ['filename', 'width', 'height', 'xmin', 'xmax', 'ymin', 'ymax'], 
        axis=1, 
        inplace=True
    )
    return df

# %%
image_dir = data_dir / 'images'
label_dir = data_dir / 'labels'
os.makedirs(image_dir, exist_ok=True)
os.makedirs(label_dir, exist_ok=True)

# %%
# create .txt annotations
for annotation_path in tqdm(annotation_paths):
    # get image_id
    image_id = annotation_path.parts[-1].split('.')[0]
    annotation_df = pd.read_csv(annotation_path)
    # transform to yolo format
    annotation_df = convert_bboxes_to_yolo_format(annotation_df, class2idx)
    # save to .txt resulting df
    with open(Path(label_dir) / f'{image_id}.txt', 'w') as f:
        f.write(annotation_df.to_string(header=False, index=False))
# Out:
#   0%|          | 8/12008 [00:00<02:46, 72.25it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#
).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ymax'] = (df['ymax'] / df['height']).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xc']   = (df['xmin'] + df['xmax']) / 2
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['yc']   = (df['ymin'] + df['ymax']) / 2
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['w']    = (df['xmax'] - df['xmin'])
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h']    = (df['ymax'] - df['ymin'])
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  17%|█▋        | 1996/12008 [00:21<01:46, 94.44it/s] C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  17%|█▋        | 2022/12008 [00:21<01:34, 106.09it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  17%|█▋        | 2034/12008 [00:21<01:46, 93.35it/s] C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  17%|█▋        | 2067/12008 [00:21<01:20, 123.57it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  17%|█▋        | 2081/12008 [00:21<01:18, 126.68it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  18%|█▊        | 2127/12008 [00:22<01:12, 136.80it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  18%|█▊        | 2187/12008 [00:22<01:10, 139.03it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  18%|█▊        | 2201/12008 [00:22<01:10, 138.23it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# ...
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['w']    = (df['xmax'] - df['xmin'])
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h']    = (df['ymax'] - df['ymin'])
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  97%|█████████▋| 11654/12008 [01:27<00:02, 174.23it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  97%|█████████▋| 11674/12008 [01:28<00:01, 180.62it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  97%|█████████▋| 11693/12008 [01:28<00:02, 154.98it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  98%|█████████▊| 11710/12008 [01:28<00:01, 154.95it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  98%|█████████▊| 11746/12008 [01:28<00:01, 163.38it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  98%|█████████▊| 11766/12008 [01:28<00:01, 171.12it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  98%|█████████▊| 11786/12008 [01:28<00:01, 177.53it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  99%|█████████▊| 11842/12008 [01:29<00:00, 174.61it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  99%|█████████▉| 11862/12008 [01:29<00:00, 179.54it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  99%|█████████▉| 11881/12008 [01:29<00:00, 173.99it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'] = df['class'].apply(lambda x: class2idx[x]).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xmin'] = (df['xmin'] / df['width']).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ymin'] = (df['ymin'] / df['height']).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xmax'] = (df['xmax'] / df['width']).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ymax'] = (df['ymax'] / df['height']).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xc']   = (df['xmin'] + df['xmax']) / 2
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['yc']   = (df['ymin'] + df['ymax']) / 2
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['w']    = (df['xmax'] - df['xmin'])
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h']    = (df['ymax'] - df['ymin'])
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  99%|█████████▉| 11899/12008 [01:29<00:00, 165.31it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  99%|█████████▉| 11916/12008 [01:29<00:00, 163.87it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
#  99%|█████████▉| 11934/12008 [01:29<00:00, 167.27it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
# 100%|█████████▉| 11951/12008 [01:29<00:00, 159.97it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
# 100%|█████████▉| 11968/12008 [01:29<00:00, 160.38it/s]C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['class'] = df['class'].apply(lambda x: class2idx[x]).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xmin'] = (df['xmin'] / df['width']).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ymin'] = (df['ymin'] / df['height']).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xmax'] = (df['xmax'] / df['width']).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ymax'] = (df['ymax'] / df['height']).values
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xc']   = (df['xmin'] + df['xmax']) / 2
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['yc']   = (df['ymin'] + df['ymax']) / 2
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['w']    = (df['xmax'] - df['xmin'])
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['h']    = (df['ymax'] - df['ymin'])
# C:\Users\Tyler\AppData\Local\Temp\ipykernel_24868\1425088543.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(
# 100%|██████████| 12008/12008 [01:30<00:00, 133.29it/s]

# %%
for image_path in image_paths:
    shutil.move(str(image_path), image_dir)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=1.3)

# %%
image_paths = [Path(image_dir) / image_path for image_path in sorted(os.listdir(image_dir))]
label_paths = [Path(label_dir) / label_path for label_path in sorted(os.listdir(label_dir))]

# %%
from sklearn.model_selection import train_test_split

# %%
image_paths = [f'images/{image_path}' for image_path in sorted(os.listdir(image_dir))]

# %%
train_size = 0.95

train_image_paths, val_image_paths = train_test_split(
    image_paths, train_size=train_size, random_state=3573, shuffle=True)

# %%
# make train split
with open(data_dir / 'train_split.txt', 'w') as f:
    f.writelines(f'./{image_path}\n' for image_path in train_image_paths)

# make val split
with open(data_dir / 'val_split.txt', 'w') as f:
    f.writelines(f'./{image_path}\n' for image_path in val_image_paths)

# %%
data_yaml = "C:\\Users\\Tyler\\Desktop\\Orig_Data_Aircraft_Detection\\data\\MilitaryAircraft.yaml"

# %%
from ultralytics import YOLO

# Load a model
#model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("C:\\Users\\Tyler\\Downloads\\yolov8x.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="C:\\Users\\Tyler\\Desktop\\Orig_Data_Aircraft_Detection\\data\\MilitaryAircraft.yaml", epochs=350,lr0=0.00001,lrf=0.00001,optimizer='SGD')  # train the model
#metrics = model.val()  # evaluate model performance on the validation set
#results = model("C:\\Users\\Tyler\\Downloads\\Plane_Model_Testing\\Object_Detection_PlanesT1.png")  # predict on an image
#path = model.export(format="onnx")  # export the model to ONNX format
# Out:
# Ultralytics YOLOv8.0.220 🚀 Python-3.11.6 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3080 Laptop GPU, 16384MiB)
# engine\trainer: task=detect, mode=train, model=C:\Users\Tyler\Downloads\yolov8x.pt, data=C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\data\MilitaryAircraft.yaml, epochs=350, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train18, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=1e-05, lrf=1e-05, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train18
# WARNING:tensorflow:From C:\Users\Tyler\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Overriding model.yaml nc=80 with nc=40
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8756488  ultralytics.nn.modules.head.Detect           [40, [320, 640, 640]]
# Model summary: 365 layers, 68191128 parameters, 68191112 gradients, 258.3 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# WARNING ⚠️ ClearML installed but not initialized correctly, not logging this run. It seems ClearML is not configured on this machine!
# To get started with ClearML, setup your own 'clearml-server' or create a free account at https://app.clear.ml
# Setup instructions can be found here: https://clear.ml/docs
# WARNING:dvclive:Can't save experiment without a Git Repo.
# Create a Git repo (`git init`) and commit (`git commit`).
# DVCLive is detected and auto logging is enabled (run 'yolo settings dvc=False' to disable).
# TensorBoard: Start with 'tensorboard --logdir runs\detect\train18', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels...:   0%|          | 0/11407 [00:00<?, ?it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 50 images, 0 backgrounds, 2 corrupt:   0%|          | 50/11407 [00:00<00:23, 483.88it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 106 images, 0 backgrounds, 4 corrupt:   1%|          | 106/11407 [00:00<00:21, 516.89it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 170 images, 0 backgrounds, 4 corrupt:   1%|▏         | 170/11407 [00:00<00:20, 555.33it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 237 images, 0 backgrounds, 7 corrupt:   2%|▏         | 237/11407 [00:00<00:18, 590.84it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 302 images, 0 backgrounds, 8 corrupt:   3%|▎         | 302/11407 [00:00<00:18, 597.52it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 364 images, 0 backgrounds, 13 corrupt:   3%|▎         | 364/11407 [00:00<00:18, 599.54it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 428 images, 0 backgrounds, 17 corrupt:   4%|▍         | 428/11407 [00:00<00:18, 609.04it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 489 images, 0 backgrounds, 20 corrupt:   4%|▍         | 489/11407 [00:00<00:20, 529.36it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 582 images, 0 backgrounds, 25 corrupt:   5%|▌         | 582/11407 [00:00<00:17, 632.59it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 650 images, 0 backgrounds, 31 corrupt:   6%|▌         | 650/11407 [00:01<00:16, 642.82it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 716 images, 0 backgrounds, 37 corrupt:   6%|▋         | 716/11407 [00:01<00:18, 593.53it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 777 images, 0 backgrounds, 41 corrupt:   7%|▋         | 777/11407 [00:01<00:17, 596.83it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 838 images, 0 backgrounds, 46 corrupt:   7%|▋         | 838/11407 [00:01<00:17, 597.62it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 900 images, 0 backgrounds, 48 corrupt:   8%|▊         | 900/11407 [00:01<00:17, 601.04it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 965 images, 0 backgrounds, 51 corrupt:   8%|▊         | 965/11407 [00:01<00:17, 612.09it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 1031 images, 0 backgrounds, 54 corrupt:   9%|▉         | 1031/11407 [00:01<00:16, 621.09it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 1097 images, 0 backgrounds, 60 corrupt:  10%|▉         | 1097/11407 [00:01<00:16, 631.09it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 1161 images, 0 backgrounds, 64 corrupt:  10%|█         | 1161/11407 [00:01<00:16, 630.51it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 1225 images, 0 backgrounds, 66 corrupt:  11%|█         | 1225/11407 [00:02<00:16, 626.44it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 1293 images, 0 backgrounds, 71 corrupt:  11%|█▏        | 1293/11407 [00:02<00:15, 633.39it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 1359 images, 0 backgrounds, 74 corrupt:  12%|█▏        | 1359/11407 [00:02<00:15, 637.96it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 1423 images, 0 backgrounds, 76 corrupt:  12%|█▏        | 1423/11407 [00:02<00:15, 633.48it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 1487 images, 0 backgrounds, 79 corrupt:  13%|█▎        | 1487/11407 [00:02<00:15, 623.10it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 1550 images, 0 backgrounds, 81 corrupt:  14%|█▎        | 1550/11407 [00:02 ...
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\005a2bac1b0045cd972c75110c0f378b.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\00ee2f5b81e8ff2f65cfa959cf30ef02.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\01c1bbe086ccd2a86ff839287bb7d7e6.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\01df70fc8d7d21e10be2655935421043.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\04cc34540ada2c5e5cd5630e634242e0.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\04fa6b69ed83ef7a780f9184f1bbeb0e.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\052d37e0cb99f1c7b583392052b653e9.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\065d8e630bd3ec7cb910dfe10eee846b.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\0761aca26eb706f1f004ad15842cbd03.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\0764ac5d1449dbcc203dc58149fff5b2.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\07c9fb260718b133b806f23cb03512a0.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\07f3476353b9428e3750b9750c7930b0.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\0829d07a49401f8d459cc5e2f495d917.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\0846b4a6d48afd6fcbc2f700babd185b.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\086e839c04393e52f2ce5152e85b3da9.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\0941945338ce153d93470639b1ef86af.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\09898008170005281c8f5ebd008a4425.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\09c3b3043f9496290a9d1099b128cd48.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\0aa1a084e8a6202a95bb1d425478a34d.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\0aec91f88f3603697c6d30be532cd5bd.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\0b0efaf65dbe4844923d8726a6c7efbc.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\
jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\ff11be860861734b4172e9f81a9810e9.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# train: New cache created: C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels.cache
# val: Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels...:   0%|          | 0/601 [00:00<?, ?it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 34 images, 0 backgrounds, 0 corrupt:   6%|▌         | 34/601 [00:00<00:01, 330.98it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 83 images, 0 backgrounds, 4 corrupt:  14%|█▍        | 83/601 [00:00<00:01, 412.17it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 126 images, 0 backgrounds, 4 corrupt:  21%|██        | 126/601 [00:00<00:01, 381.47it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 174 images, 0 backgrounds, 4 corrupt:  29%|██▉       | 174/601 [00:00<00:01, 390.83it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 215 images, 0 backgrounds, 5 corrupt:  36%|███▌      | 215/601 [00:00<00:00, 394.90it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 263 images, 0 backgrounds, 8 corrupt:  44%|████▍     | 263/601 [00:00<00:00, 409.35it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 304 images, 0 backgrounds, 10 corrupt:  51%|█████     | 305/601 [00:00<00:00, 319.25it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 368 images, 0 backgrounds, 12 corrupt:  61%|██████▏   | 369/601 [00:00<00:00, 397.64it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 412 images, 0 backgrounds, 14 corrupt:  69%|██████▊   | 413/601 [00:01<00:00, 406.97it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 456 images, 0 backgrounds, 18 corrupt:  76%|███████▌  | 457/601 [00:01<00:00, 407.41it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 499 images, 0 backgrounds, 18 corrupt:  83%|████████▎ | 500/601 [00:01<00:00, 402.84it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 544 images, 0 backgrounds, 18 corrupt:  91%|█████████ | 545/601 [00:01<00:00, 412.82it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 587 images, 0 backgrounds, 21 corrupt:  98%|█████████▊| 588/601 [00:01<00:00, 383.39it/s]Scanning C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels... 600 images, 0 backgrounds, 22 corrupt: 100%|██████████| 601/601 [00:01<00:00, 391.81it/s]
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\1132a1dcba79950db0ef65ceade75add.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\19bb9fe1a60bf3e834b9a43212cb9e90.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\1abfb8ef640d7eede0c84b1a706a9949.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\1b520bead342c72a25fe64c0905d1f48.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\5030921b665384085daa3afb447869c3.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\5f729ba291a7df8ce2242f0dcd5fd9ce.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\64777bc58c059c922eb2a7bc449860a3.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\649252d4c9603d4a8563c0be3ec6a840.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\7497b6886cf4d2afbeb4898e1d174ac9.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\7e722a1478e888c2d0b8bffeb7bbb154.jpg: ignoring corrupt image/label: image file is truncated (1 bytes not processed)
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\843ad2802a9040338bd401b39c2380da.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\9980c40e359d038ed5516444b04e949c.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\a7492b07b96e130ce830fa9ab07b9c7f.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\af97224e6565834d42554443e42fe9fc.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\b3086ae3659165b35b50c620301a6493.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\b51c5315cb5b7f488aa5cf051bfe1ce2.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\bb3d424386219bb7332bdc0a8cf0ffcf.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\c08985548d2db655d85090aadb40205e.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\eecfd837ea8541826d40b3beed0eee8b.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\ef468fbf9ab838f3e56426c7e517ef63.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\fa499dc36019f1747248ece867070a3c.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: WARNING ⚠️ C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\images\fd6e6bb295bbcbd34f0b9fda02346ef7.jpg: ignoring corrupt image/label: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
# val: New cache created: C:\Users\Tyler\Desktop\Orig_Data_Aircraft_Detection\labels.cache
# Plotting labels to runs\detect\train18\labels.jpg...
# optimizer: SGD(lr=1e-05, momentum=0.937) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs\detect\train18
# Starting training for 350 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/350      14.9G     0.8568      4.804      1.259          7        640: 100%|██████████| 685/685 [10:12<00:00,  1.12it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 19/19 [00:09<00:00,  1.94it/s]
#                    all        579        853     0.0106      0.203     0.0131     0.0118
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#   0%|          | 0/685 [00:00<?, ?it/s]

# %%
from ultralytics import YOLO
model = YOLO("C:\\Users\\Tyler\\AppData\\Local\\Programs\\Microsoft VS Code\\runs\\detect\\train8\\weights\\best.pt")

# %%
import cv2
from sahi import AutoDetectionModel
from sahi.predict import get_prediction
from pathlib import Path
from ultralytics.utils.files import increment_path
from sahi.utils.yolov8 import download_yolov8l_model

def run(weights, source, view_img=False, save_img=False, exist_ok=False):
    # Check source path
    if not Path(source).exists():
        raise FileNotFoundError(f"Source path '{source}' does not exist.")

    # Download YOLOv8 model
    yolov8_model_path = weights
    download_yolov8l_model(yolov8_model_path)
    detection_model = AutoDetectionModel.from_pretrained(model_type='yolov8',
                                                         model_path=yolov8_model_path,
                                                         confidence_threshold=0.80,
                                                         device='cuda:0')
    # Video setup
    videocapture = cv2.VideoCapture(source)
    frame_width, frame_height = int(videocapture.get(3)), int(videocapture.get(4))
    fps, fourcc = int(videocapture.get(5)), cv2.VideoWriter_fourcc(*'mp4v')

    # Output setup
    save_dir = increment_path(Path('ultralytics_results_with_sahi') / 'exp', exist_ok)
    save_dir.mkdir(parents=True, exist_ok=True)
    video_writer = cv2.VideoWriter(str(save_dir / f'{Path(source).stem}.mp4'), fourcc, fps, (frame_width, frame_height))

    while videocapture.isOpened():
        success, frame = videocapture.read()
        if not success:
            break

        results = get_prediction(frame,
                                        detection_model,)
        object_prediction_list = results.object_prediction_list

        boxes_list = []
        clss_list = []
        for ind, _ in enumerate(object_prediction_list):
            boxes = object_prediction_list[ind].bbox.minx, object_prediction_list[ind].bbox.miny, \
                object_prediction_list[ind].bbox.maxx, object_prediction_list[ind].bbox.maxy
            clss = object_prediction_list[ind].category.name
            boxes_list.append(boxes)
            clss_list.append(clss)

        for box, cls in zip(boxes_list, clss_list):
            x1, y1, x2, y2 = box
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (56, 56, 255), 2)
            label = str(cls)
            t_size = cv2.getTextSize(label, 0, fontScale=0.8, thickness=1)[0]
            cv2.rectangle(frame, (int(x1), int(y1) - t_size[1] - 3), (int(x1) + t_size[0], int(y1) + 3), (56, 56, 255),
                          -1)
            cv2.putText(frame,
                        label, (int(x1), int(y1) - 2),
                        0,
                        0.6, [255, 255, 255],
                        thickness=1,
                        lineType=cv2.LINE_AA)

        if view_img:
            cv2.imshow(Path(source).stem, frame)
        if save_img:
            video_writer.write(frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    video_writer.release()
    videocapture.release()
    cv2.destroyAllWindows()


# Example usage in Jupyter Notebook
weights = "C:\\Users\\Tyler\\Desktop\\Orig_Data_Aircraft_Detection\\data\\runs\\detect\\train8\\weights\\best.pt"
source = "C:\\Users\\Tyler\\Downloads\\Aircraft_Video_Test.mp4"
run(weights, source, view_img=True, save_img=False, exist_ok=False)
